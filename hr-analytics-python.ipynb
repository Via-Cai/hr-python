# %% [markdown]
# ## DATA SCIENCE PROJECT ON H.R DATA-SET OF I.B.M COMPANY (USA)

# %% [markdown]
# ##### Importing The Python Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ##### Importing The Dataset

# %%
# Link of data set = https://www.kaggle.com/datasets/pavansubhasht/ibm-hr-analytics-attrition-dataset

#Read the CSV file
df = pd.read_csv(r"C:\Users\llivi\OneDrive\Desktop\hr-python\hr-python.csv")

# To see all columns in the dataset
pd.set_option('display.max_columns', None)

# Display the first 5 rows
df.head(10)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
# 5   32        No  Travel_Frequently       1005  Research & Development
# 6   59        No      Travel_Rarely       1324  Research & Development
# 7   30        No      Travel_Rarely       1358  Research & Development
# 8   38        No  Travel_Frequently        216  Research & Development
# 9   36        No      Travel_Rarely       1299  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# ...

# %% [markdown]
# ##### Dataset Explanation

# %%
# Check all the columns in the dataframe
print(df.columns)


# Total number of columns in the dataframe
length_of_column = len(df.columns)

print(f'The total number of columns is: {length_of_column}')
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')
# The total number of columns is: 35

# %% [markdown]
# ##### Getting to know the data
# Uncover the factors that lead to employee attrition and explore important questions such as ‘show me a breakdown of distance from home by job role and attrition’ or ‘compare average monthly income by education and attrition’. This is a fictional data set created by IBM data scientists.
#
# | Column Name                     | Data Type      | Description                                              |
# |---------------------------------|----------------|----------------------------------------------------------|
# | Age                             | Integer        | The age of the employee.                                 |
# | Attrition                       | Categorical     | Indicates whether the employee has left the company.     |
# | BusinessTravel                  | Categorical     | Frequency of business travel (e.g., Frequent, Rare, None).  |
# | DailyRate                       | Float          | Daily salary rate of the employee.                       |
# | Department                      | Categorical     | The department where the employee works.                 |
# | DistanceFromHome                | Integer        | Distance from home to workplace (in kilometers).         |
# | Education                       | Categorical     | The highest level of education attained by the employee. |
# | EducationField                  | Categorical     | Field of education (e.g., Science, Arts).               |
# | EmployeeCount                   | Integer        | Total number of employees in the company.                |
# | EmployeeNumber                  | Integer        | Unique identifier for each employee.                     |
# | EnvironmentSatisfaction         | Integer        | Satisfaction level with the work environment (1-4 scale).|
# | Gender                          | Categorical     | Gender of the employee (e.g., Male, Female).            |
# | HourlyRate                      | Float          | Hourly salary rate of the employee.                      |
# | JobInvolvement                  | Integer        | Level of job involvement (1-4 scale).                    |
# | JobLevel                        | Integer        | Level of the job (1-5 scale).                           |
# | JobRole                         | Categorical     | Role of the employee in the company.                     |
# | JobSatisfaction                 | Integer        | Satisfaction level with the job (1-5 scale).            |
# | MaritalStatus                   | Categorical     | Marital status of the employee (e.g., Married, Single). |
# | MonthlyIncome                   | Float          | Monthly income of the employee.                           |
# | MonthlyRate                     | Float          | Monthly salary rate of the employee.                     |
# | NumCompaniesWorked              | Integer        | Number of companies the employee has worked for.        |
# | Over18                          | Categorical     | Indicates if the employee is over 18 years old.         |
# | OverTime                        | Categorical     | Indicates if the employee works overtime.                |
# | PercentSalaryHike              | Integer        | Percentage increase in salary.                           |
# | PerformanceRating               | Integer        | Rating of employee performance (1-5 scale).              |
# | RelationshipSatisfaction        | Integer        | Satisfaction level with relationships at work (1-5 scale). |
# | StandardHours                   | Integer        | Standard working hours per week.                         |
# | StockOptionLevel                | Integer        | Level of stock options available (0-3 scale).           |
# | TotalWorkingYears               | Integer        | Total years of work experience.                          |
# | TrainingTimesLastYear          | Integer        | Number of training sessions attended in the last year.   |
# | WorkLifeBalance                 | Integer        | Work-life balance satisfaction level (1-4 scale).       |
# | YearsAtCompany                  | Integer        | Total years worked at the company.                       |
# | YearsInCurrentRole             | Integer        | Years worked in the current role.                        |
# | YearsSinceLastPromotion         | Integer        | Years since the last promotion.                          |
# | YearsWithCurrManager            | Integer        | Years worked with the current manager.                   |

# %% [markdown]
# ##### Basic Checks

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
##### The number of attrition
atttrition_count = df['Attrition'].value_counts()
print(atttrition_count)

business_travel_count = df['BusinessTravel'].value_counts()
print(business_travel_count)
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64
# BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: count, dtype: int64

# %%
# Count occurrences of each category
attrition_counts = df['Attrition'].value_counts()

# Create the bar plot using pyplot
plt.figure(figsize=(6, 4))
plt.bar(attrition_counts.index, attrition_counts.values, color=['#3274a1', '#424242'])

# Annotate the counts on the bars
for index, value in enumerate(attrition_counts.values):
    plt.text(index, value, str(value), ha='center', va='bottom', fontsize=10, color='black', weight='bold')

# Set title and labels
plt.title("Attrition Bar Chart")
plt.xlabel("Attrition")
plt.ylabel("Count")
plt.ylim(0, max(attrition_counts.values) + 150)  # Adjust y-axis limit for better spacing
plt.show()

# %% [markdown]
# * Data shows that there are more number of employees who are still in the company.

# %% [markdown]
# #### IMPACT OF BUSINESS TRAVEL ON ATTRITION

# %%
sns.countplot(hue=df.Attrition, x=df.BusinessTravel)
plt.show()
